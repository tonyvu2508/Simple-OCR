# %% [markdown]
# # Simple HandWriting OCR
#
# This simple handwriting will involve custom CNN model by using Tensorflow.
# <br>I will call it MinimNet and it can be found in model.py
#
# ## 1. Import All and Prepare the Dataset
# Before going on, we could download the dataset from the [link Sueiras](https://s3-eu-west-1.amazonaws.com/handwriting-curated-database/curated.tar.gz) have given.<br>
# And just unzip the file in the same directory of this notebook.

# %%
from model2 import MinimNet
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imutils import resize, grab_contours
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from PIL import Image
import numpy as np
import cv2
import os
import bitstring
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782644197.700078   70840 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# import all needed libraries and functions needed
#
# And before we are going to prepare the dataset, we would want to set our parameters first
#
# 1. Dataset path,
# 2. Image size,
# 3. Batch size,
# 4. Number of epochs,
# 5. Initial Learning Rate (LR)
# 6. Ratio of train/test

# %%
notebook_path = os.path.abspath('Simple-OCR_runpod.ipynb')
dataset_path = os.path.dirname(notebook_path)+'/curated'
etl1_dir = os.path.join(os.path.dirname(notebook_path), 'ETL/ETL1')
etl1_paths = [
    os.path.join(etl1_dir, f) for f in os.listdir(etl1_dir) if f.startswith('ETL1C_')
] if os.path.exists(etl1_dir) else []

image_size = (32, 32)
batch_size = 512
epoch = 100
init_lr = 1e-1
test_ratio = .25

# %% [markdown]
# After putting all the needed parameters, we then will try to load the images from the path we defined
#
# We will need both the image and label, which the label is the folder name (ASCII Decimal)
#
# Thus we need somekind of label to make it more uniformed.<br> Then we will make a classLabels that consist of needed images to train.
#
# After that we will load all of the images that we need along with the labels<br>
# And change the labels into a one-hot label.

# %%
import os
import random
import numpy as np
import bitstring
from PIL import Image, ImageDraw
from scipy.ndimage import maximum_filter

# =====================================================================
# 0. KHỞI TẠO CẤU HÌNH VÀ HÀM BỔ TRỢ (HELPER FUNCTIONS)
# =====================================================================
# Cập nhật danh sách nhãn đầy đủ bao gồm cả '[' và ']' ở cuối
classLabels = "1234567890ABCDEFGHIJKLMNOPQRSTUVWXYZ[]"
classLabels = [i for i in classLabels]

# Giữ nguyên cấu hình mảng chứa dữ liệu tổng hợp cuối cùng
img = []
lbl = []

# Kiểm tra an toàn xem các biến cấu hình từ cell trước đã tồn tại chưa
if 'image_size' not in locals() and 'image_size' not in globals():
    image_size = (32, 32) # Giá trị mặc định nếu cell trước chưa chạy

if 'dataset_path' not in locals() and 'dataset_path' not in globals():
    dataset_path = "./dataset" # Giá trị mặc định chống lỗi sập code

def make_it_bold(img_array):
    """Làm đậm nét chữ bằng thuật toán giãn nở (Morphological Dilation)."""
    return maximum_filter(img_array, size=(3, 3))


def generate_realistic_brackets(char, num_samples=1000, img_size=(32, 32)):
    """Sinh dữ liệu dấu '[' hoặc ']' giả lập góc méo, nét ko đều thực tế."""
    synthetic_imgs = []
    W, H = img_size
    
    for _ in range(num_samples):
        canvas = Image.new('L', (64, 64), color=0)
        draw = ImageDraw.Draw(canvas)
        
        cx, cy = 32, 32
        h_half = random.randint(14, 20)  
        w_len = random.randint(8, 12)    
        
        # NÉT KHÔNG ĐỀU: Nét dọc và nét ngang có độ dày ngẫu nhiên độc lập
        thick_vertical = random.randint(3, 6)   
        thick_horizontal = random.randint(2, 4) 
        
        # GÓC MÉO: Lệch góc vuông (tính bằng pixel lệch ở đầu mút)
        skew_top = random.randint(-3, 3)    
        skew_bottom = random.randint(-3, 3) 
        skew_vertical = random.randint(-2, 2) 
        
        if char == '[':
            v_top = (cx - w_len//2 + skew_vertical, cy - h_half)
            v_bottom = (cx - w_len//2 - skew_vertical, cy + h_half)
            
            h_top_end = (v_top[0] + w_len, v_top[1] + skew_top)
            h_bottom_end = (v_bottom[0] + w_len, v_bottom[1] + skew_bottom)
            
            draw.line([v_top, v_bottom], fill=255, width=thick_vertical)
            draw.line([v_top, h_top_end], fill=255, width=thick_horizontal)
            draw.line([v_bottom, h_bottom_end], fill=255, width=thick_horizontal)
            
        else: 
            v_top = (cx + w_len//2 + skew_vertical, cy - h_half)
            v_bottom = (cx + w_len//2 - skew_vertical, cy + h_half)
            
            h_top_end = (v_top[0] - w_len, v_top[1] + skew_top)
            h_bottom_end = (v_bottom[0] - w_len, v_bottom[1] + skew_bottom)
            
            draw.line([v_top, v_bottom], fill=255, width=thick_vertical)
            draw.line([v_top, h_top_end], fill=255, width=thick_horizontal)
            draw.line([v_bottom, h_bottom_end], fill=255, width=thick_horizontal)
            
        # GÓC NGHIÊNG TOÀN BỘ DẤU
        angle = random.uniform(-12, 12)
        canvas = canvas.rotate(angle, resample=Image.BICUBIC)
        
        # DỊCH CHUYỂN VỊ TRÍ (Translation)
        shift_x = random.randint(-3, 3)
        shift_y = random.randint(-3, 3)
        left = (64 - W) // 2 + shift_x
        top = (64 - H) // 2 + shift_y
        
        canvas = canvas.crop((left, top, left + W, top + H))
        
        img_array = np.array(canvas) * (1. / 255.)
        synthetic_imgs.append(img_array)
        
    return synthetic_imgs


def load_etl1_data(file_paths, class_labels, img_size=(32, 32)):
    """Đọc dữ liệu từ ETL1 và sinh thêm phiên bản nét đậm."""
    etl_img = []
    etl_lbl = []
    
    for file_path in file_paths:
        if not os.path.exists(file_path):
            print(f"⚠️ ETL file không tồn tại: {file_path}")
            continue
            
        print(f"Đang đọc ETL file: {file_path}...")
        file_size = os.path.getsize(file_path)
        record_size = 2052
        num_records = file_size // record_size
        
        with open(file_path, "rb") as f:
            for i in range(num_records):
                _bytes = f.read(record_size)
                if len(_bytes) < record_size:
                    break
                    
                f_bit = bitstring.ConstBitStream(bytes=_bytes)
                r = f_bit.readlist('uint:16,bytes:2,uint:16,hex:8,hex:8,4*uint:8,uint:32,4*uint:16,4*uint:8,pad:32,bytes:2016,pad:32')
                char_code = r[1][0]
                img_bytes = r[18]
                
                if 32 <= char_code <= 126:
                    char = chr(char_code)
                    if char in class_labels:
                        lbl_idx = class_labels.index(char)
                        pixels = []
                        for b in img_bytes:
                            p1 = (b >> 4) & 0x0F
                            p2 = b & 0x0F
                            pixels.extend([p1, p2])
                            
                        img_array = 255 - (np.array(pixels, dtype=np.uint8) * 17)
                        img_array = img_array.reshape(63, 64)
                        
                        img_obj = Image.fromarray(img_array).resize(img_size)
                        img_array_norm = np.array(img_obj) * (1. / 255.)
                        
                        # Ảnh gốc ETL1
                        img_tensor_orig = np.expand_dims(img_array_norm, axis=-1)
                        etl_img.append(img_tensor_orig)
                        etl_lbl.append(lbl_idx)
                        
                        # Ảnh nét đậm ETL1
                        img_bold = make_it_bold(img_array_norm)
                        img_tensor_bold = np.expand_dims(img_bold, axis=-1)
                        etl_img.append(img_tensor_bold)
                        etl_lbl.append(lbl_idx)
                                        
    return etl_img, etl_lbl


# =====================================================================
# 1. XỬ LÝ CURATED DATASET (ĐỌC GỐC + SINH ĐẬM)
# =====================================================================
if os.path.exists(dataset_path):
    print("Bắt đầu xử lý Curated Dataset...")
    for folder in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder)
        
        if os.path.isdir(folder_path):
            try:
                folder_char = chr(int(folder))
            except ValueError:
                continue
                
            if folder_char in classLabels:
                lbl_idx = classLabels.index(folder_char)
                
                for file in os.listdir(folder_path):
                    if file.startswith('.'):
                        continue
                    
                    file_path = os.path.join(folder_path, file)
                    
                    try:
                        image_obj = Image.open(file_path).resize(image_size)
                        img_array = np.array(image_obj) * (1. / 255.)
                        
                        # Thêm ảnh gốc
                        img_tensor_orig = np.expand_dims(img_array, axis=-1)
                        img.append(img_tensor_orig)
                        lbl.append(lbl_idx)
                        
                        # Thêm ảnh nét đậm
                        img_bold = make_it_bold(img_array)
                        img_tensor_bold = np.expand_dims(img_bold, axis=-1)
                        img.append(img_tensor_bold)
                        lbl.append(lbl_idx)
                        
                    except Exception as e:
                        print(f"⚠️ Bỏ qua file lỗi: {file_path} | Chi tiết: {e}")

img = np.array(img, dtype='float32') if len(img) > 0 else np.empty((0, *image_size, 1), dtype='float32')
lbl = np.array(lbl) if len(lbl) > 0 else np.empty((0,), dtype='int64')
print(f"✅ Đã tải và sinh nét đậm thành công: {len(img)} ảnh từ curated dataset.")


# =====================================================================
# 2. TỰ SINH DỮ LIỆU NGOẶC THỰC TẾ CHO '[' VÀ ']' (GỐC + ĐẬM)
# =====================================================================
print("Bắt đầu tự sinh dữ liệu cho ký tự '[' và ']'...")
bracket_chars = ['[', ']']
num_samples_per_char = 1500  

bracket_imgs = []
bracket_lbls = []

for char in bracket_chars:
    lbl_idx = classLabels.index(char)
    syn_imgs = generate_realistic_brackets(char, num_samples=num_samples_per_char, img_size=image_size)
    
    for img_arr in syn_imgs:
        # Ảnh tự sinh gốc
        img_tensor_orig = np.expand_dims(img_arr, axis=-1)
        bracket_imgs.append(img_tensor_orig)
        bracket_lbls.append(lbl_idx)
        
        # Ảnh tự sinh nét đậm
        img_bold = make_it_bold(img_arr)
        img_tensor_bold = np.expand_dims(img_bold, axis=-1)
        bracket_imgs.append(img_tensor_bold)
        bracket_lbls.append(lbl_idx)

if len(bracket_imgs) > 0:
    bracket_imgs = np.array(bracket_imgs, dtype='float32')
    bracket_lbls = np.array(bracket_lbls)
    
    if len(img) > 0:
        img = np.concatenate([img, bracket_imgs], axis=0)
        lbl = np.concatenate([lbl, bracket_lbls], axis=0)
    else:
        img = bracket_imgs
        lbl = bracket_lbls
    print(f"✅ Đã tự sinh và gộp thêm {len(bracket_imgs)} ảnh cho ký tự '[' và ']'.")


# =====================================================================
# 3. ĐỌC VÀ GỘP THÊM ETL1 SỬ DỤNG BIẾN ĐÃ CÓ SẴN (GỐC + ĐẬM)
# =====================================================================
# Sử dụng trực tiếp biến `etl1_paths` của bạn đã định nghĩa ở cell trước
if 'etl1_paths' in locals() or 'etl1_paths' in globals():
    if len(etl1_paths) > 0:
        etl_img, etl_lbl = load_etl1_data(etl1_paths, classLabels, image_size)
        if len(etl_img) > 0:
            img = np.concatenate([img, np.array(etl_img, dtype='float32')], axis=0)
            lbl = np.concatenate([lbl, np.array(etl_lbl)], axis=0)
            print(f"✅ Đã tải và sinh nét đậm thành công: {len(etl_img)} ảnh từ ETL1.")
else:
    print("⚠️ Không tìm thấy biến `etl1_paths` được định nghĩa từ trước.")


# =====================================================================
# 4. KẾT QUẢ ĐẦU RA TỔNG HỢP
# =====================================================================
print("\n--- THÔNG TIN TẬP DỮ LIỆU CUỐI CÙNG ---")
print(f"✅ Tổng số lượng ảnh: {len(img)}")
print(f"✅ Shape tổng thể của tập dữ liệu: {img.shape}")
print(f"✅ Shape của tập nhãn: {lbl.shape}")
# Out:
# Bắt đầu xử lý Curated Dataset...
# ✅ Đã tải và sinh nét đậm thành công: 53554 ảnh từ curated dataset.
# Bắt đầu tự sinh dữ liệu cho ký tự '[' và ']'...
# ✅ Đã tự sinh và gộp thêm 6000 ảnh cho ký tự '[' và ']'.
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_13...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_12...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_11...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_10...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_09...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_08...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_07...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_06...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_05...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_04...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_02...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_01...
# Đang đọc ETL file: /workspace/ETL/ETL1/ETL1C_03...
# ✅ Đã tải và sinh nét đậm thành công: 222560 ảnh từ ETL1.
#
# --- THÔNG TIN TẬP DỮ LIỆU CUỐI CÙNG ---
# ✅ Tổng số lượng ảnh: 282114
# ✅ Shape tổng thể của tập dữ liệu: (282114, 32, 32, 1)
# ✅ Shape của tập nhãn: (282114,)

# %%
#create a one-hot label
le = LabelBinarizer()
lbl = le.fit_transform(lbl)

#count the total number of images per class
classTotals = lbl.sum(axis=0)
classWeight = {}

#create a custom weight for every class
for i in range(len(classTotals)):
    classWeight[i] = classTotals.max() / classTotals[i]
    
#split the class to train and test using scikit train_test_split
(trainImg, testImg, trainLbl, testLbl) = train_test_split(img, lbl,
                                                         test_size = test_ratio,
                                                         stratify = lbl,
                                                         random_state = 42)

# %% [markdown]
# After we done in splitting the dataset, we will proceed to the next step.
# <br><br>
#
# ## 2. Create the Model to train
#
# As I have said before, we will try to build a model.<br>
# This model will be consisting of some layers such as:
# 1. Bottleneck Layer,
# 2. Inverted Bottleneck Layer,
# 3. Squeeze Global Layer,
# 4. SE Module.
#
# The model could be checked in the Model.py or in the summary below.

# %%
model = MinimNet((image_size[0], image_size[1], 1), len(classTotals))
model.summary()

from tensorflow.keras.optimizers.schedules import InverseTimeDecay
# lr_schedule = InverseTimeDecay(
#     initial_learning_rate=init_lr,
#     decay_steps=1,
#     decay_rate=init_lr / epoch
# )
# Define hyperparameters
initial_learning_rate = 0.1
decay_steps = 1.0  # Decays smoothly at every single continuous step
decay_rate = 0.01

# Instantiate the built-in schedule
lr_schedule = InverseTimeDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=decay_steps,
    decay_rate=decay_rate,
    staircase=False # Set to True if you want discrete step decay instead of continuous
)
opt = SGD(learning_rate=lr_schedule)
# opt = SGD(learning_rate=init_lr)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy'])
# Out:
# I0000 00:00:1782644247.960247   70840 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10115 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:2e:00.0, compute capability: 8.6
# Model: "MinimNet_MaxAcc"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        288 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 32, 32,    │        288 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ activation_1[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 8)   │        264 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1, 32)  │        288 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ activation_1[0][… │
# │                     │ 32)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │        512 │ multiply[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │      1,024 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 16, 16,    │        576 │ activation_2[0][… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation_3[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1, 1, 16)  │      1,040 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1, 1, 64)  │      1,088 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16, 16,    │          0 │ activation_3[0][… │
# │ (Multiply)          │ 64)               │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │      2,048 │ multiply_1[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │      4,096 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 16, 16,    │      1,152 │ activation_4[0][… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_5[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 128) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1, 1, 32)  │      4,128 │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1, 1, 128) │      4,224 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 16, 16,    │          0 │ activation_5[0][… │
# │ (Multiply)          │ 128)              │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │      4,096 │ multiply_2[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │      4,096 │ add[0][0]         │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 8, 8, 128) │      1,152 │ activation_6[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_7[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 128) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1, 1, 32)  │      4,128 │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1, 1, 128) │      4,224 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 8, 8, 128) │          0 │ activation_7[0][… │
# │ (Multiply)          │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 8, 64)  │      8,192 │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │     16,384 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (None, 8, 8, 256) │      2,304 │ activation_8[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_9[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 256) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1, 1, 64)  │     16,448 │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1, 1, 256) │     16,640 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 8, 8, 256) │          0 │ activation_9[0][… │
# │ (Multiply)          │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 64)  │     16,384 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 8, 256) │     16,384 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (None, 8, 8, 256) │      2,304 │ activation_10[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_11[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1, 1, 256) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1, 1, 64)  │     16,448 │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 1, 1, 256) │     16,640 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 8, 8, 256) │          0 │ activation_11[0]… │
# │ (Multiply)          │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, 8, 64)  │     16,384 │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 8, 8, 64)  │          0 │ add_1[0][0],      │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 8, 8, 384) │     24,576 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,536 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 4, 4, 384) │      3,456 │ activation_12[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 384) │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 4, 4, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ activation_13[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1, 384) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 1, 1, 96)  │     36,960 │ reshape_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1, 1, 384) │     37,248 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 4, 4, 384) │          0 │ activation_13[0]… │
# │ (Multiply)          │                   │            │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 4, 4, 128) │     49,152 │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 4, 4, 768) │     98,304 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 768) │      3,072 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 4, 4, 768) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (None, 4, 4, 768) │      6,912 │ activation_14[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 768) │      3,072 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 4, 4, 768) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ activation_15[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 1, 1, 768) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 1, 1, 192) │    147,648 │ reshape_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 1, 1, 768) │    148,224 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 4, 4, 768) │          0 │ activation_15[0]… │
# │ (Multiply)          │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 4, 4, 128) │     98,304 │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 4, 4, 768) │     98,304 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 768) │      3,072 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 4, 4, 768) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (None, 4, 4, 768) │      6,912 │ activation_16[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 768) │      3,072 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 4, 4, 768) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ activation_17[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 1, 768) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 1, 1, 192) │    147,648 │ reshape_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1, 1, 768) │    148,224 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 4, 4, 768) │          0 │ activation_17[0]… │
# │ (Multiply)          │                   │            │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 4, 4, 128) │     98,304 │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 4, 4, 128) │          0 │ add_3[0][0],      │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 4, 4, 768) │     98,304 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 768) │      3,072 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 4, 4, 768) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (None, 4, 4, 768) │      6,912 │ activation_18[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 768) │      3,072 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 4, 4, 768) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ activation_19[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, 1, 1, 768) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 1, 1, 192) │    147,648 │ reshape_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 1, 1, 768) │    148,224 │ dense_18[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 4, 4, 768) │          0 │ activation_19[0]… │
# │ (Multiply)          │                   │            │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 4, 4, 256) │    196,608 │ multiply_9[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 4, 4, 512) │    131,072 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ activation_20[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 38)        │     19,494 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,115,774 (8.07 MB)
#  Trainable params: 2,098,718 (8.01 MB)
#  Non-trainable params: 17,056 (66.62 KB)

# %% [markdown]
# Now after we have the model, it is time to start training the model.
#
# ## 3. Train the model
#
# Now, we will make an augmentation for the training batch so that it could have more variations of the dataset.<br>
# We will also make an additional module from tensorflow such as:
#
# 1. EarlyStopping : To stop the training if there's no improvement on the monitored variable,
# 2. ModelCheckpoint : To save the model/weight if it reached higher value on the monitored variable,
# 3. ReduceLROnPlateau : To reduce the LR if there's no improvement on the monitored variable.

# %%
aug = ImageDataGenerator(rotation_range=10, zoom_range=.05,
                        width_shift_range=.1, height_shift_range=.1,
                        shear_range=.15, horizontal_flip=False,
                        fill_mode='nearest')

eS = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mChk = ModelCheckpoint('OCR Model.h5', save_best_only=True, monitor='val_loss', mode='min')
rLR = ReduceLROnPlateau(monitor='val_loss', factor=.01, patience=10, verbose=1, min_lr=1e-6, mode='min')

# %%
h = model.fit(aug.flow(trainImg, trainLbl, batch_size=batch_size),
             validation_data=(testImg, testLbl),
             steps_per_epoch=len(trainImg)//batch_size,
             epochs=epoch, callbacks=[eS, mChk, rLR],
             class_weight=classWeight, verbose=2)
# Out:
# Epoch 1/100
# I0000 00:00:1782644249.090567   70840 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# I0000 00:00:1782644253.086180   71019 service.cc:153] XLA service 0x7c4d9804fb00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782644253.086207   71019 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 3080 Ti, Compute Capability 8.6 (Driver: 13.0.0; Runtime: 12.4.0; Toolkit: 12.5.0; DNN: 9.23.2)
# I0000 00:00:1782644253.328770   71019 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1782644254.022004   71019 cuda_dnn.cc:461] Loaded cuDNN version 92302
# I0000 00:00:1782644254.201391   71019 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_13533__.325
# E0000 00:00:1782644255.790340   71019 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1782644259.288753   71019 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1782644261.094439   71019 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1782644261.404304   71168 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_154', 52 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1782644261.468199   71019 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1782644261.754631   71152 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_146', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1782644261.820462   71019 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1782644263.924183   71019 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1782644265.640672   71019 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.

# %% [markdown]
# After training, we will plot the result of the training, such as the loss and accuracy.
#
# Here, we will use the pyplot to plot the result into an image called Result.png

# %%
n = np.array(range(len(h.history['loss'])))
plt.style.use('ggplot')
plt.figure()
plt.plot(n, h.history['loss'], label='Train_loss')
plt.plot(n, h.history['val_loss'], label='Val_loss')
plt.title=('Training Accuracy and Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(loc='lower left')
plt.savefig('Result.png')

# %% [markdown]
# Then we will test it, and show each class result in F1 score using sklearn classification_report

# %%
predictions = model.predict(testImg, batch_size=batch_size)
print(classification_report(testLbl.argmax(axis=1),
                            predictions.argmax(axis=1), target_names=classLabels))

# %% [markdown]
# And its finished! But only for the model part.
#
# Next, we will combine this with OpenCV to make it into real OCR and read multiple character in the images at once.
#
# ## 4. Combining with OpenCV
# In this step we will:
# 1. Load an image containing handwriting using OpenCV,
# 2. Convert the image into Grayscale,
# 3. Apply some image processing,
# 4. Get the contours and sort them from left to right,
# 5. Crop images based on the contours,
# 6. Predict each image from the cropped image,
# 7. Append the result to the image.

# %%
# put all the needed variable/parameter
file_name = 'image_to_test.jpg'
image_path = os.path.dirname(notebook_path)+'/'+file_name

image_to_test = cv2.imread(image_path)

#convert to grayscale
gray = cv2.cvtColor(image_to_test, cv2.COLOR_BGR2GRAY)
#blurring the image
blur = cv2.GaussianBlur(gray, (5, 5), 0)

#apply edge filter to the blurred image
edge = cv2.Canny(blur, 30, 150)

# %%
#get contours
cntrs = cv2.findContours(edge.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cntrs = grab_contours(cntrs)

#sort contours from top left to bottom right
boundingBox = [cv2.boundingRect(c) for c in cntrs]
(cntrs, _) = zip(*sorted(zip(cntrs, boundingBox), key=lambda x: (-x[1][1], x[1][0])))

# %%
char_detected = []

for c in cntrs:
    (x,y,w,h) = cv2.boundingRect(c)
    
    #attemp to ignore small contours
    if (w >= 5 and w <= 350) and (h >= 15 and h <= 320):
        #create an Region of Interest
        roi = gray[y:y+h, x:x+w]
        
        #threshold it to make it into binary image
        bin_img = cv2.threshold(roi, 0 ,255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
        (iH, iW) = bin_img.shape
        
        #if imageWidth(iW) is bigger than the Height, then we will scale the image until
        #the width is equal to 32, else scale the image until we got the height is the 32
        #32 used in here is based on the image_size which is (32,32)
        if iW > iH:
            bin_img = resize(bin_img, width = image_size[0])
        else:
            bin_img = resize(bin_img, height = image_size[1])
            
        #update with the new image size
        (iH, iW) = bin_img.shape
        dX = int(max(0, 32 - iW) / 2.0)
        dY = int(max(0, 32 - iH) / 2.0)
        
        #pad the image and resize it to match the input of the model
        padded = cv2.copyMakeBorder(bin_img, top=dY, bottom=dY,
            left=dX, right=dX, borderType=cv2.BORDER_CONSTANT,
            value=(0, 0, 0))
        padded = cv2.resize(padded, image_size)
        
        #normalize the image so that it got the same value of testImg
        padded = padded.astype("float32") / 255.0
        padded = np.expand_dims(padded, axis=-1)
        
        #put it into list of the queue of images to predict
        char_detected.append([padded, (x, y, w, h)])
        
#get each location and image of detected char
boxes = [b[1] for b in char_detected]
char_detected = np.array([c[0] for c in char_detected], dtype="float32")
#feed it as the input of the model
predictions = model.predict(char_detected)
preds = []
for pred in predictions:
    i = np.argmax(pred)
    prob = pred[i]
    preds.append([classLabels[i], prob])

for (pred, (x, y, w, h)) in zip(preds, boxes):
    #put the result into the image and print it
    print("[DETECTED CHAR] {} - {:.2f}%".format(pred[0], pred[1] * 100))
    cv2.rectangle(image_to_test, (x, y), (x + w, y + h), (0, 255, 0), 2)
    cv2.putText(image_to_test, "{}".format(pred[0]), (x - 10, y - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 255, 0), 2)

#show the result
cv2.imwrite("Image_after_test.jpg", image_to_test)

# %%
#show the result
plt.imshow(image_to_test)

# %% [markdown]
# As we can see the result shows:
# <br>
# "This is only a jimple ocr 2020 thij nekds momd troaining"
#
# There are some errors on the S and The insides of R, which always shows up as D or O.<br>
# And RE that connected also read as M.
#
# And that's it! Congratulation, you have reached the end of this tutorial!
#
# But as we can see that the result is still not that good.<br>
# There are still things that we can do to fix this such as:
# 1. Make the the minimum size bigger,
# 2. Maybe train it more or try to use other network,
# 3. Try to train using other dataset.
